# %%
model.save('model(realA100).h5')  # creates a HDF5 file 'my_model.h5'
del model

# %%
import os
import random
import numpy as np
import PIL
from time import time
from PIL import Image
from builtins import range
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.models import load_model
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras import backend as K
K.set_image_dim_ordering('th')
from sklearn.model_selection import train_test_split


def read_images (path , sz=None):
    c = 0
    X,y = [], []
    for  dirname , dirnames , filenames  in os.walk(path):
        for  subdirname  in  dirnames:
            subject_path = os.path.join(dirname , subdirname)
            for  filename  in os.listdir(subject_path):
                try:
                    im = Image.open(os.path.join(subject_path , filename))
                    #im = im.convert("L")
# resize  to  given  size (if  given)
                    if (sz is not  None):
                        im = im.resize(sz, Image.ANTIALIAS)
                    X.append(np.asarray(im , dtype=np.uint8))
                    y.append(c)
                except  IOError:
                    print "I/O error ({0}): {1}".format(errno , strerror)
                except:
                    print "Unexpected  error:", sys.exc_info ()[0]
                    raise
            c = c+1
    return [X,y]

[X , y ] =read_images( "/home/pramod/Downloads/project/datax100" )

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50,random_state=42)
t1=time()
X_train=np.array(X_train)
X_test=np.array(X_test[0:5])

# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 1,100,100).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 1,100,100).astype('float32')

# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255
# one hot encode outputs
Y_train = np_utils.to_categorical(y_train)
Y_test = np_utils.to_categorical(y_test)
num_classes = Y_test.shape[1]

def baseline_model():
    # create model
    model = Sequential()
    model.add(Convolution2D(32,5,5, border_mode='valid', input_shape=(1,100,100),activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(128,init='normal', activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    # Compile model
    return model


model = baseline_model()

model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# Fit the model
model.fit(X_train, Y_train, nb_epoch=5 , batch_size=4, verbose=1)
# Final evaluation of the model
a=model.predict(X_test[0:5])
y_pred = np.argmax(a, axis=1)

print y_pred
print y_test[0:5]
print("done in %0.3fs" % (time() - t1))
scores = model.evaluate(X_test, Y_test[0:5], verbose=0)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
print ("test score is ",scores[0])
print ('test accuracy is ', scores[1])
# Out:
# Using TensorFlow backend.
# Epoch 1/5
# 72/72 [==============================] - 8s - loss: 3.0685 - acc: 0.0972
# Epoch 2/5
# 72/72 [==============================] - 8s - loss: 2.4324 - acc: 0.2222
# Epoch 3/5
# 72/72 [==============================] - 8s - loss: 2.3022 - acc: 0.3194
# Epoch 4/5
# 72/72 [==============================] - 8s - loss: 1.8882 - acc: 0.4306
# Epoch 5/5
# 72/72 [==============================] - 8s - loss: 1.3737 - acc: 0.6250
# [10 10  4  8  4]
# [9, 1, 6, 8, 4]
# done in 43.501s
# Baseline Error: 60.00%
# ('test score is ', 1.7587015628814697)
# ('test accuracy is ', 0.40000000596046448)

# %%
---------------#execute above and below separately------------------------

# %%
import os
import random
import numpy as np
import PIL
from PIL import Image
from builtins import range
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.models import load_model
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras import backend as K
import keras
from time import time
K.set_image_dim_ordering('th')
from sklearn.model_selection import train_test_split



def read_images (path , sz=None):
    c = 0
    X,y = [], []
    for  dirname , dirnames , filenames  in os.walk(path):
        for  subdirname  in  dirnames:
            subject_path = os.path.join(dirname , subdirname)
            for  filename  in os.listdir(subject_path):
                try:
                    im = Image.open(os.path.join(subject_path , filename))
                    #im = im.convert("L")
# resize  to  given  size (if  given)
                    if (sz is not  None):
                        im = im.resize(sz, Image.ANTIALIAS)
                    X.append(np.asarray(im , dtype=np.uint8))
                    y.append(c)
                except  IOError:
                    print "I/O error ({0}): {1}".format(errno , strerror)
                except:
                    print "Unexpected  error:", sys.exc_info ()[0]
                    raise
            c = c+1
    return [X,y]


[X , y ] =read_images( "/home/pramod/Downloads/project/datax100" )

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50,random_state=42)
t1=time()

X_train=np.array(X_train)
X_test=np.array(X_test)

# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 1,100,100).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 1,100,100).astype('float32')

# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255
# one hot encode outputs
Y_train = np_utils.to_categorical(y_train)
Y_test = np_utils.to_categorical(y_test)
num_classes = Y_test.shape[1]
print num_classes

def larger_model():
    model = Sequential()
    model.add(Convolution2D(15, 5, 5, border_mode='valid', input_shape=(1, 100,100), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Convolution2D(30, 3, 3, activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(36, activation='tanh'))
    model.add(Dense(num_classes, activation='softmax'))
# Compile model
    return model

model = larger_model()
# Fit the model
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

model.fit(X_train, Y_train, validation_data=(X_test, Y_test), nb_epoch=10, batch_size=3, verbose=1)

a=model.predict(X_test)
y_pred = np.argmax(a, axis=1)

print y_pred
print y_test
print("done in %0.3fs" % (time() - t1))
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
print ("test score is ",scores[0])
print ('test accuracy is ', scores[1])
# Out:
# 12
# Train on 65 samples, validate on 65 samples
# Epoch 1/10
# 65/65 [==============================] - 5s - loss: 2.5812 - acc: 0.0615 - val_loss: 2.4614 - val_acc: 0.2000
# Epoch 2/10
# 65/65 [==============================] - 5s - loss: 2.3941 - acc: 0.2308 - val_loss: 2.5215 - val_acc: 0.1231
# Epoch 3/10
# 65/65 [==============================] - 5s - loss: 2.1139 - acc: 0.4000 - val_loss: 2.3241 - val_acc: 0.1846
# Epoch 4/10
# 65/65 [==============================] - 5s - loss: 1.8298 - acc: 0.4923 - val_loss: 2.1059 - val_acc: 0.3385
# Epoch 5/10
# 65/65 [==============================] - 5s - loss: 1.3719 - acc: 0.6462 - val_loss: 1.7374 - val_acc: 0.4923
# Epoch 6/10
# 65/65 [==============================] - 5s - loss: 0.8985 - acc: 0.8769 - val_loss: 1.6464 - val_acc: 0.4769
# Epoch 7/10
# 65/65 [==============================] - 5s - loss: 0.6057 - acc: 0.9077 - val_loss: 1.3040 - val_acc: 0.6462
# Epoch 8/10
# ...

# %%
model.save('model(realA100)(large).h5')  # creates a HDF5 file 'my_model.h5'
del model
